# %%
library(ggplot2)
library(tidyverse)
#library(dpylr)
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.1.0     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
#
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
rides <- read.csv('/Volumes/GabeTB/Data/chicago/chicago-ride-hailing-2M.csv')

# %%
head(rides)
# Out:
#   X trip_id                                  trip_start_timestamp
# 1 0 0129b022cee56537e694cfbe60ada953a77b3968 2021-07-31T23:45:00.000
# 2 1 0f292a85a95ea47ee76387651ba472d21619b67a 2021-07-31T23:45:00.000
# 3 2 1793de09e7863c2fbfad4b4c1da394d8f0d31e7d 2021-07-31T23:45:00.000
# 4 3 0d6a5ab2b79792a4ea5564019570e31fb4bbfb1a 2021-07-31T23:45:00.000
# 5 4 0fde4eea78c5ed6f8f435c421854be18b2888001 2021-07-31T23:45:00.000
# 6 5 017a04c6441a9a572bcc2c2c6660b4f61feb9504 2021-07-31T23:45:00.000
#   trip_end_timestamp      trip_seconds trip_miles pickup_census_tract
# 1 2021-08-01T00:00:00.000  267         1.2503     17031080300
# 2 2021-08-01T00:00:00.000  472         1.2457     17031081800
# 3 2021-08-01T00:00:00.000  364         0.8563     17031241400
# 4 2021-08-01T00:00:00.000 1074         4.2342     17031330100
# 5 2021-07-31T23:45:00.000  334         1.3574     17031839100
# 6 2021-07-31T23:45:00.000  367         1.8512              NA
# ...

# %%
ggplot(aes(rides$trip_miles))
# Out:
# plot without title
